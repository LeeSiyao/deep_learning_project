# %%
任务：基于task1_data1、task1_data2数据，建立mlp模型，并实现模型迁移学习：

1、基于data1完成基本的数据加载、可视化工作；
2、建立mlp模型，epochs分别为500、1000、1500、2500次，可视化数据预测结果
3、模型存储为model1及加载为model2
4、基于data2，对model2进行迁移训练，epochs=20、100，可视化模型对数据的预测结果
拓展任务：逐步增加epochs，生成预测结果gif，查看迁移学习过程

模型结构：两个隐藏层，每层50神经元（激活函数relu），输出层激活函数linear

# %%
# 数据加载
import numpy as np
import pandas as pd
data1 = pd.read_csv('task1_data1.csv') 
data1.head()
# Out:
#       x         y
# 0 -10.0  0.544021
# 1  -9.8  0.366479
# 2  -9.6  0.174327
# 3  -9.4 -0.024775
# 4  -9.2 -0.222890

# %%
# x,y赋值
x = data1.loc[:,'x']
y = data1.loc[:,'y']
x.head()
# Out:
# 0   -10.0
# 1    -9.8
# 2    -9.6
# 3    -9.4
# 4    -9.2
# Name: x, dtype: float64

# %%
# 数据可视化
from matplotlib import pyplot as plt
fig1 = plt.figure()
plt.scatter(x,y)
plt.title('data 1')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
# 维度确认
print(x.shape,y.shape)
x = np.array(x)# MLP对x有特征数要求，y没有。
x = x.reshape(-1,1)
# Out:
# (101, 1) (101,)

# %%
# MLP模型建立
from keras.models import Sequential
from keras.layers import Dense
model_mlp = Sequential()
model_mlp.add(Dense(units=50,input_dim=1,activation='relu'))
model_mlp.add(Dense(units=50,activation='relu'))
model_mlp.add(Dense(units=1,activation='linear'))
model_mlp.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_4 (Dense)              (None, 50)                100
# _________________________________________________________________
# dense_5 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 51
# ...
# Total params: 2,701
# Trainable params: 2,701
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 参数配置
model_mlp.compile(optimizer='adam',loss='mean_squared_error') # 非线性回归任务所以损失函数是均方差
model_mlp.fit(x,y,epochs=500)
# Out:
# Epoch 1/500
# 101/101 [==============================] - 0s 2ms/step - loss: 1.5872
# Epoch 2/500
# 101/101 [==============================] - 0s 49us/step - loss: 0.8047
# Epoch 3/500
# 101/101 [==============================] - 0s 59us/step - loss: 0.5071
# Epoch 4/500
# 101/101 [==============================] - 0s 69us/step - loss: 0.4843
# Epoch 5/500
# 101/101 [==============================] - 0s 49us/step - loss: 0.5170
# Epoch 6/500
# 101/101 [==============================] - 0s 69us/step - loss: 0.5052
# Epoch 7/500
# 101/101 [==============================] - 0s 59us/step - loss: 0.4820
# Epoch 8/500
# 101/101 [==============================] - 0s 59us/step - loss: 0.4676
# Epoch 9/500
# 101/101 [==============================] - 0s 59us/step - loss: 0.4657
# Epoch 10/500
# 101/101 [==============================] - 0s 50us/step - loss: 0.4664
# Epoch 11/500
# 101/101 [==============================] - 0s 59us/step - loss: 0.4649
# Epoch 12/500
# ...

# %%
# 模型预测与表现评估
y_predict = model_mlp.predict(x)
# r2 score
from sklearn.metrics import r2_score
r2 = r2_score(y,y_predict)
print(r2)
# Out:
# 0.6491720190530493

# %%
# 预测结果可视化
fig2 = plt.figure()
plt.scatter(x,y,label='y_real')
plt.scatter(x,y_predict,label='y_predict')
plt.title('predict vs real')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
# 模型训练 1000
model_mlp.fit(x,y,epochs=500)
# Out:
# Epoch 1/500
# 101/101 [==============================] - 0s 49us/step - loss: 0.1688
# Epoch 2/500
# 101/101 [==============================] - 0s 59us/step - loss: 0.1684
# Epoch 3/500
# 101/101 [==============================] - 0s 49us/step - loss: 0.1651
# Epoch 4/500
# 101/101 [==============================] - 0s 59us/step - loss: 0.1674
# Epoch 5/500
# 101/101 [==============================] - 0s 49us/step - loss: 0.1703
# Epoch 6/500
# 101/101 [==============================] - 0s 49us/step - loss: 0.1760
# Epoch 7/500
# 101/101 [==============================] - 0s 59us/step - loss: 0.1725
# Epoch 8/500
# 101/101 [==============================] - 0s 69us/step - loss: 0.1682
# Epoch 9/500
# 101/101 [==============================] - 0s 69us/step - loss: 0.1676
# Epoch 10/500
# 101/101 [==============================] - 0s 69us/step - loss: 0.1663
# Epoch 11/500
# 101/101 [==============================] - 0s 49us/step - loss: 0.1699
# Epoch 12/500
# ...

# %%
y_predict = model_mlp.predict(x)
# r2 score
from sklearn.metrics import r2_score
r2 = r2_score(y,y_predict)
print(r2)
# 预测结果可视化
fig2 = plt.figure()
plt.scatter(x,y,label='y_real')
plt.scatter(x,y_predict,label='y_predict')
plt.title('predict vs real')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# 0.8732446204387183

# %%
# 模型训练 1500
model_mlp.fit(x,y,epochs=500)
# Out:
# Epoch 1/500
# 101/101 [==============================] - 0s 49us/step - loss: 0.0603
# Epoch 2/500
# 101/101 [==============================] - 0s 59us/step - loss: 0.0622
# Epoch 3/500
# 101/101 [==============================] - 0s 49us/step - loss: 0.0608
# Epoch 4/500
# 101/101 [==============================] - 0s 59us/step - loss: 0.0625
# Epoch 5/500
# 101/101 [==============================] - 0s 69us/step - loss: 0.0637
# Epoch 6/500
# 101/101 [==============================] - 0s 69us/step - loss: 0.0679
# Epoch 7/500
# 101/101 [==============================] - 0s 69us/step - loss: 0.0667
# Epoch 8/500
# 101/101 [==============================] - 0s 49us/step - loss: 0.0608
# Epoch 9/500
# 101/101 [==============================] - 0s 59us/step - loss: 0.0591
# Epoch 10/500
# 101/101 [==============================] - 0s 69us/step - loss: 0.0648
# Epoch 11/500
# 101/101 [==============================] - 0s 79us/step - loss: 0.0663
# Epoch 12/500
# ...

# %%
y_predict = model_mlp.predict(x)
# r2 score
from sklearn.metrics import r2_score
r2 = r2_score(y,y_predict)
print(r2)
# 预测结果可视化
fig2 = plt.figure()
plt.scatter(x,y,label='y_real')
plt.scatter(x,y_predict,label='y_predict')
plt.title('predict vs real')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# 0.9907665611386492

# %%
# 模型训练 2000
model_mlp.fit(x,y,epochs=500)
# Out:
# Epoch 1/500
# 101/101 [==============================] - 0s 59us/step - loss: 0.0098
# Epoch 2/500
# 101/101 [==============================] - 0s 49us/step - loss: 0.0127
# Epoch 3/500
# 101/101 [==============================] - 0s 49us/step - loss: 0.0049
# Epoch 4/500
# 101/101 [==============================] - 0s 49us/step - loss: 0.0085
# Epoch 5/500
# 101/101 [==============================] - 0s 49us/step - loss: 0.0054
# Epoch 6/500
# 101/101 [==============================] - 0s 49us/step - loss: 0.0047
# Epoch 7/500
# 101/101 [==============================] - 0s 59us/step - loss: 0.0041
# Epoch 8/500
# 101/101 [==============================] - 0s 79us/step - loss: 0.0049
# Epoch 9/500
# 101/101 [==============================] - 0s 59us/step - loss: 0.0045
# Epoch 10/500
# 101/101 [==============================] - 0s 79us/step - loss: 0.0037
# Epoch 11/500
# 101/101 [==============================] - 0s 79us/step - loss: 0.0047
# Epoch 12/500
# ...

# %%
y_predict = model_mlp.predict(x)
# r2 score
from sklearn.metrics import r2_score
r2 = r2_score(y,y_predict)
print(r2)
# 预测结果可视化
fig2 = plt.figure()
plt.scatter(x,y,label='y_real')
plt.scatter(x,y_predict,label='y_predict')
plt.title('predict vs real')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# 0.998420845174798

# %%
# 模型迁移
# 模型存储
import joblib
joblib.dump(model_mlp,'model_mlp.m')
# Out:
# ['model_mlp.m']

# %%
# 模型加载
model2 = joblib.load('model_mlp.m')
model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_4 (Dense)              (None, 50)                100
# _________________________________________________________________
# dense_5 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 51
# ...
# Total params: 2,701
# Trainable params: 2,701
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 加载新数据
data2 = pd.read_csv('task1_data2.csv')
data2.head()
x2 = data2.loc[:,'x']
y2 = data2.loc[:,'y']
x2 = np.array(x2)
x2 = x2.reshape(-1,1)
print(x2.shape)
# Out:
# (88, 1)

# %%
y2_predict = model2.predict(x2)
# r2 score
r2 = r2_score(y2,y2_predict)
print(r2) # 负数说明预测非常准确
# Out:
# -4.174627983349884

# %%
# model2结果可视化
fig4 = plt.figure()
plt.scatter(x2,y2,label='y2_real')
plt.scatter(x2,y2_predict,label='y2_predict')
plt.title('predict vs real')
plt.xlabel('x2')
plt.ylabel('y2')
plt.legend()
plt.show()

# %%
# 进行迁移学习
# 用新的数据集训练模型
model2.fit(x2,y2,epochs=500)
# Out:
# Epoch 1/500
# 88/88 [==============================] - 0s 1ms/step - loss: 7.4990
# Epoch 2/500
# 88/88 [==============================] - 0s 45us/step - loss: 1.6592
# Epoch 3/500
# 88/88 [==============================] - 0s 45us/step - loss: 3.1085
# Epoch 4/500
# 88/88 [==============================] - 0s 68us/step - loss: 2.0122
# Epoch 5/500
# 88/88 [==============================] - 0s 45us/step - loss: 0.8726
# Epoch 6/500
# 88/88 [==============================] - 0s 57us/step - loss: 1.1060
# Epoch 7/500
# 88/88 [==============================] - 0s 68us/step - loss: 0.9555
# Epoch 8/500
# 88/88 [==============================] - 0s 57us/step - loss: 0.5644
# Epoch 9/500
# 88/88 [==============================] - 0s 57us/step - loss: 0.4908
# Epoch 10/500
# 88/88 [==============================] - 0s 57us/step - loss: 0.4773
# Epoch 11/500
# 88/88 [==============================] - 0s 45us/step - loss: 0.3685
# Epoch 12/500
# ...

# %%
y2_predict = model2.predict(x2)
# r2 score
r2 = r2_score(y2,y2_predict)
print(r2) # 负数说明预测非常准确
# Out:
# 0.9968118184448175

# %%
# model2结果可视化
fig5 = plt.figure()
plt.scatter(x2,y2,label='y2_real')
plt.scatter(x2,y2_predict,label='y2_predict')
plt.title('predict vs real')
plt.xlabel('x2')
plt.ylabel('y2')
plt.legend()
plt.show()
